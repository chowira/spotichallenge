# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
import pandas as pd
import requests

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = "2fde000873cf4db7b4e490116ba9976c"
client_secret ="5234a1e0a6744153a44ab59d9685fb3f" # CLIENT SECRET
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQD7CoPlrgcez22WbGma0csEy2cAmSvl7YWS0pHedZUpXgHdwap_U9KywmsF6sggX-wG_Py_QXSJ2njtlhC4XWZ2M3i9ynEe41k0y_drmyevW5GK_qY',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}
             # {'Authorization': f'Bearer {access_toke}

# %%
header_info
# Out:
# {'Authorization': 'Bearer BQD7CoPlrgcez22WbGma0csEy2cAmSvl7YWS0pHedZUpXgHdwap_U9KywmsF6sggX-wG_Py_QXSJ2njtlhC4XWZ2M3i9ynEe41k0y_drmyevW5GK_qY'}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI

full_endpoint = base_url + resource  + "790FomKkXshlbRYZFtlgla"+ "/related-artists"
full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla/related-artists'

# %%
https://api.spotify.com/v1/artists/{id}/related-artists

# %%
r = requests.get(full_endpoint, headers=header_info)
r.status_code
# Out:
# 200

# %%
r_json
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0tmwSHipWxN12fsoLcFU3B'},
#    'followers': {'href': None, 'total': 14113454},
#    'genres': ['colombian pop',
#     'latin pop',
#     'reggaeton',
#     'reggaeton colombiano',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/0tmwSHipWxN12fsoLcFU3B',
#    'id': '0tmwSHipWxN12fsoLcFU3B',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebcc91276af455a0fbc0ac56d0',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174cc91276af455a0fbc0ac56d0',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178cc91276af455a0fbc0ac56d0',
#      'height': 160,
#      'width': 160}],
#    'name': 'Manuel Turizo',
#    'popularity': 84,
#    'type': 'artist',
#    'uri': 'spotify:artist:0tmwSHipWxN12fsoLcFU3B'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1r4hJ1h58CWwUQe3MxPuau'},
#    'followers': {'href': None, 'total': 34755746},
#    'genres': ['latin pop',
#     'reggaeton',
#     'reggaeton colombiano',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau',
#    'id': '1r4hJ1h58CWwUQe3MxPuau',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb4ad532b705df9f1a8b3fe314',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051744ad532b705df9f1a8b3fe314',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1784ad532b705df9f1a8b3fe314',
#      'height': 160,
#      'width': 160}],
#    'name': 'Maluma',
#    'popularity': 86,
#    'type': 'artist',
#    'uri': 'spotify:artist:1r4hJ1h58CWwUQe3MxPuau'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4obzFoKoKRHIphyHzJ35G3'},
#    'followers': {'href': None, 'total': 15178241},
#    'genres': ['latin pop',
#     'latin viral pop',
#     'rap latina',
#     'reggaeton',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/4obzFoKoKRHIphyHzJ35G3',
#    'id': '4obzFoKoKRHIphyHzJ35G3',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb689f28b643fd40a523e00a96',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174689f28b643fd40a523e00a96',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178689f28b643fd40a523e00a96',
#      'height': 160,
#      'width': 160}],
#    'name': 'Becky G',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:4obzFoKoKRHIphyHzJ35G3'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#    'followers': {'href': None, 'total': 23903843},
#    'genres': ['puerto rican pop', 'reggaeton', 'trap latino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#    'id': '1mcTU81TzQhprhouKaTkpq',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eba0881fe672e4e39f9ec0a9e0',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174a0881fe672e4e39f9ec0a9e0',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178a0881fe672e4e39f9ec0a9e0',
#      'height': 160,
#      'width': 160}],
#    'name': 'Rauw Alejandro',
#    'popularity': 90,
#    'type': 'artist',
#    'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2LRoIwlKmHjgvigdNGBHNo'},
#    'followers': {'href': None, 'total': 14318679},
#    'genres': ['colombian pop',
#     'pop reggaeton',
#     'reggaeton',
#     'reggaeton colombiano',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/2LRoIwlKmHjgvigdNGBHNo',
#    'id': '2LRoIwlKmHjgvigdNGBHNo',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebe82c62cc8cf019aecfd71ee8',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174e82c62cc8cf019aecfd71ee8',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178e82c62cc8cf019aecfd71ee8',
#      'height': 160,
#      'width': 160}],
#    'name': 'Feid',
#    'popularity': 92,
#    'type': 'artist',
#    'uri': 'spotify:artist:2LRoIwlKmHjgvigdNGBHNo'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2NfSBtmWe7oPw1EmetJVso'},
#    'followers': {'href': None, 'total': 614908},
#    'genres': ['panamanian pop', 'reggaeton', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/2NfSBtmWe7oPw1EmetJVso',
#    'id': '2NfSBtmWe7oPw1EmetJVso',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb67e69bfa7e97cd5c2d35f032',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab6761610000517467e69bfa7e97cd5c2d35f032',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f17867e69bfa7e97cd5c2d35f032',
#      'height': 160,
#      'width': 160}],
#    'name': 'Boza',
#    'popularity': 71,
#    'type': 'artist',
#    'uri': 'spotify:artist:2NfSBtmWe7oPw1EmetJVso'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#    'followers': {'href': None, 'total': 86418310},
#    'genres': ['reggaeton', 'trap latino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#    'id': '4q3ewBCX7sLwd24euuV69X',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb744a4243fb6cc938011a98f4',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174744a4243fb6cc938011a98f4',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178744a4243fb6cc938011a98f4',
#      'height': 160,
#      'width': 160}],
#    'name': 'Bad Bunny',
#    'popularity': 95,
#    'type': 'artist',
#    'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1i8SpTcr7yvPOmcqrbnVXY'},
#    'followers': {'href': None, 'total': 37540985},
#    'genres': ['puerto rican pop', 'reggaeton', 'trap latino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/1i8SpTcr7yvPOmcqrbnVXY',
#    'id': '1i8SpTcr7yvPOmcqrbnVXY',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebc80f303b208a480f52e8180b',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174c80f303b208a480f52e8180b',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178c80f303b208a480f52e8180b',
#      'height': 160,
#      'width': 160}],
#    'name': 'Ozuna',
#    'popularity': 87,
#    'type': 'artist',
#    'uri': 'spotify:artist:1i8SpTcr7yvPOmcqrbnVXY'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3m5qlPf2OkihLz3dRYnkPA'},
#    'followers': {'href': None, 'total': 469630},
#    'genres': ['colombian pop',
#     'reggaeton',
#     'reggaeton colombiano',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/3m5qlPf2OkihLz3dRYnkPA',
#    'id': '3m5qlPf2OkihLz3dRYnkPA',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb05e06a9536017820309375d7',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab6761610000517405e06a9536017820309375d7',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f17805e06a9536017820309375d7',
#      'height': 160,
#      'width': 160}],
#    'name': 'Ovy On The Drums',
#    'popularity': 79,
#    'type': 'artist',
#    'uri': 'spotify:artist:3m5qlPf2OkihLz3dRYnkPA'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vyhD5VmyZ7KMfW5gqLgo5'},
#    'followers': {'href': None, 'total': 37281059},
#    'genres': ['reggaeton',
#     'reggaeton colombiano',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/1vyhD5VmyZ7KMfW5gqLgo5',
#    'id': '1vyhD5VmyZ7KMfW5gqLgo5',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebdea08796d296a58c5d060439',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174dea08796d296a58c5d060439',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178dea08796d296a58c5d060439',
#      'height': 160,
#      'width': 160}],
#    'name': 'J Balvin',
#    'popularity': 88,
#    'type': 'artist',
#    'uri': 'spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7jAs1uPnpfNmT6e5qtEPxq'},
#    'followers': {'href': None, 'total': 48602},
#    'genres': [],
#    'href': 'https://api.spotify.com/v1/artists/7jAs1uPnpfNmT6e5qtEPxq',
#    'id': '7jAs1uPnpfNmT6e5qtEPxq',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb444eae7e928cddfd6cd254ee',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174444eae7e928cddfd6cd254ee',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178444eae7e928cddfd6cd254ee',
#      'height': 160,
#      'width': 160}],
#    'name': 'ATL Jacob',
#    'popularity': 74,
#    'type': 'artist',
#    'uri': 'spotify:artist:7jAs1uPnpfNmT6e5qtEPxq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/28gNT5KBp7IjEOQoevXf9N'},
#    'followers': {'href': None, 'total': 19341069},
#    'genres': ['colombian pop',
#     'latin pop',
#     'latin viral pop',
#     'reggaeton colombiano',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/28gNT5KBp7IjEOQoevXf9N',
#    'id': '28gNT5KBp7IjEOQoevXf9N',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb4d8a681290f905bc52a05c5c',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051744d8a681290f905bc52a05c5c',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1784d8a681290f905bc52a05c5c',
#      'height': 160,
#      'width': 160}],
#    'name': 'Camilo',
#    'popularity': 81,
#    'type': 'artist',
#    'uri': 'spotify:artist:28gNT5KBp7IjEOQoevXf9N'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/37230BxxYs9ksS7OkZw3IU'},
#    'followers': {'href': None, 'total': 1215835},
#    'genres': ['reggaeton', 'reggaeton flow', 'trap latino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/37230BxxYs9ksS7OkZw3IU',
#    'id': '37230BxxYs9ksS7OkZw3IU',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb7ab9ab65a8d38cad451d3417',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051747ab9ab65a8d38cad451d3417',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1787ab9ab65a8d38cad451d3417',
#      'height': 160,
#      'width': 160}],
#    'name': 'Chencho Corleone',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:37230BxxYs9ksS7OkZw3IU'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/07YUOmWljBTXwIseAUd9TW'},
#    'followers': {'href': None, 'total': 23172166},
#    'genres': ['colombian pop',
#     'latin pop',
#     'reggaeton',
#     'reggaeton colombiano',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/07YUOmWljBTXwIseAUd9TW',
#    'id': '07YUOmWljBTXwIseAUd9TW',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb1f347feae6a2afbf3ffb364a',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051741f347feae6a2afbf3ffb364a',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1781f347feae6a2afbf3ffb364a',
#      'height': 160,
#      'width': 160}],
#    'name': 'Sebastian Yatra',
#    'popularity': 80,
#    'type': 'artist',
#    'uri': 'spotify:artist:07YUOmWljBTXwIseAUd9TW'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5H1nN1SzW0qNeUEZvuXjAj'},
#    'followers': {'href': None, 'total': 5607362},
#    'genres': ['pop venezolano', 'reggaeton', 'trap latino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/5H1nN1SzW0qNeUEZvuXjAj',
#    'id': '5H1nN1SzW0qNeUEZvuXjAj',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb9ef435d044d9bff59226ce45',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051749ef435d044d9bff59226ce45',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1789ef435d044d9bff59226ce45',
#      'height': 160,
#      'width': 160}],
#    'name': 'Danny Ocean',
#    'popularity': 78,
#    'type': 'artist',
#    'uri': 'spotify:artist:5H1nN1SzW0qNeUEZvuXjAj'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3UTF2no3muGdiFXVujl94i'},
#    'followers': {'href': None, 'total': 248434},
#    'genres': [],
#    'href': 'https://api.spotify.com/v1/artists/3UTF2no3muGdiFXVujl94i',
#    'id': '3UTF2no3muGdiFXVujl94i',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebd21af7619db28f072b7a9f54',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174d21af7619db28f072b7a9f54',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178d21af7619db28f072b7a9f54',
#      'height': 160,
#      'width': 160}],
#    'name': 'Kapo',
#    'popularity': 81,
#    'type': 'artist',
#    'uri': 'spotify:artist:3UTF2no3muGdiFXVujl94i'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5lwmRuXgjX8xIwlnauTZIP'},
#    'followers': {'href': None, 'total': 22783712},
#    'genres': ['bachata',
#     'latin hip hop',
#     'latin pop',
#     'trap latino',
#     'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP',
#    'id': '5lwmRuXgjX8xIwlnauTZIP',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb6d8b48abede0f9e433aa6e49',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051746d8b48abede0f9e433aa6e49',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1786d8b48abede0f9e433aa6e49',
#      'height': 160,
#      'width': 160}],
#    'name': 'Romeo Santos',
#    'popularity': 85,
#    'type': 'artist',
#    'uri': 'spotify:artist:5lwmRuXgjX8xIwlnauTZIP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#    'followers': {'href': None, 'total': 35261319},
#    'genres': ['latin hip hop', 'reggaeton', 'trap latino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#    'id': '4VMYDCV2IEDYJArk749S6m',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5ebaa534de724c7a565c07bb3f5',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab67616100005174aa534de724c7a565c07bb3f5',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f178aa534de724c7a565c07bb3f5',
#      'height': 160,
#      'width': 160}],
#    'name': 'Daddy Yankee',
#    'popularity': 88,
#    'type': 'artist',
#    'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#    'followers': {'href': None, 'total': 35010089},
#    'genres': ['colombian pop', 'dance pop', 'latin pop', 'pop'],
#    'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#    'id': '0EmeFodog0BfCgMzAIvKQp',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb2528c726e5ddb90a7197e527',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab676161000051742528c726e5ddb90a7197e527',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f1782528c726e5ddb90a7197e527',
#      'height': 160,
#      'width': 160}],
#    'name': 'Shakira',
#    'popularity': 88,
#    'type': 'artist',
#    'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1DxLCyH42yaHKGK3cl5bvG'},
#    'followers': {'href': None, 'total': 7103515},
#    'genres': ['pop argentino', 'urbano latino'],
#    'href': 'https://api.spotify.com/v1/artists/1DxLCyH42yaHKGK3cl5bvG',
#    'id': '1DxLCyH42yaHKGK3cl5bvG',
#    'images': [{'url': 'https://i.scdn.co/image/ab6761610000e5eb77a953d390a2dfa7482899cb',
#      'height': 640,
#      'width': 640},
#     {'url': 'https://i.scdn.co/image/ab6761610000517477a953d390a2dfa7482899cb',
#      'height': 320,
#      'width': 320},
#     {'url': 'https://i.scdn.co/image/ab6761610000f17877a953d390a2dfa7482899cb',
#      'height': 160,
#      'width': 160}],
#    'name': 'Maria Becerra',
#    'popularity': 82,
#    'type': 'artist',
#    'uri': 'spotify:artist:1DxLCyH42yaHKGK3cl5bvG'}]}

# %%
r_json = r.json()

# %%
type(r_json)
# Out:
# dict

# %%
r_json.keys()
# Out:
# dict_keys(['artists'])

# %%
r_list = r_json["artists"]

# %%
type(r_list)
# Out:
# list

# %%
len(r_list)
# Out:
# 20

# %%
for i in range(len(r_list)):
    print(r_list[i]["name"])
# Out:
# Manuel Turizo
# Maluma
# Becky G
# Rauw Alejandro
# Feid
# Boza
# Bad Bunny
# Ozuna
# Ovy On The Drums
# J Balvin
# ATL Jacob
# Camilo
# Chencho Corleone
# Sebastian Yatra
# Danny Ocean
# Kapo
# Romeo Santos
# Daddy Yankee
# Shakira
# Maria Becerra

# %%
artitas_relacionasdos = pd.DataFrame(r_list)

# %%
artitas_relacionasdos
# Out:
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/artist/0...
# 1   {'spotify': 'https://open.spotify.com/artist/1...
# 2   {'spotify': 'https://open.spotify.com/artist/4...
# 3   {'spotify': 'https://open.spotify.com/artist/1...
# 4   {'spotify': 'https://open.spotify.com/artist/2...
# 5   {'spotify': 'https://open.spotify.com/artist/2...
# 6   {'spotify': 'https://open.spotify.com/artist/4...
# 7   {'spotify': 'https://open.spotify.com/artist/1...
# 8   {'spotify': 'https://open.spotify.com/artist/3...
# 9   {'spotify': 'https://open.spotify.com/artist/1...
# 10  {'spotify': 'https://open.spotify.com/artist/7...
# 11  {'spotify': 'https://open.spotify.com/artist/2...
# 12  {'spotify': 'https://open.spotify.com/artist/3...
# 13  {'spotify': 'https://open.spotify.com/artist/0...
# 14  {'spotify': 'https://open.spotify.com/artist/5...
# 15  {'spotify': 'https://open.spotify.com/artist/3...
# 16  {'spotify': 'https://open.spotify.com/artist/5...
# 17  {'spotify': 'https://open.spotify.com/artist/4...
# 18  {'spotify': 'https://open.spotify.com/artist/0...
# 19  {'spotify': 'https://open.spotify.com/artist/1...
#
#                             followers  \
# 0   {'href': None, 'total': 14113454}
# 1   {'href': None, 'total': 34755746}
# 2   {'href': None, 'total': 15178241}
# 3   {'href': None, 'total': 23903843}
# 4   {'href': None, 'total': 14318679}
# 5     {'href': None, 'total': 614908}
# 6   {'href': None, 'total': 86418310}
# 7   {'href': None, 'total': 37540985}
# 8     {'href': None, 'total': 469630}
# 9   {'href': None, 'total': 37281059}
# 10     {'href': None, 'total': 48602}
# 11  {'href': None, 'total': 19341069}
# 12   {'href': None, 'total': 1215835}
# 13  {'href': None, 'total': 23172166}
# 14   {'href': None, 'total': 5607362}
# 15    {'href': None, 'total': 248434}
# 16  {'href': None, 'total': 22783712}
# 17  {'href': None, 'total': 35261319}
# 18  {'href': None, 'total': 35010089}
# 19   {'href': None, 'total': 7103515}
#
#                                                genres  \
# 0   [colombian pop, latin pop, reggaeton, reggaeto...
# 1   [latin pop, reggaeton, reggaeton colombiano, t...
# 2   [latin pop, latin viral pop, rap latina, regga...
# 3   [puerto rican pop, reggaeton, trap latino, urb...
# 4   [colombian pop, pop reggaeton, reggaeton, regg...
# 5          [panamanian pop, reggaeton, urbano latino]
# 6             [reggaeton, trap latino, urbano latino]
# 7   [puerto rican pop, reggaeton, trap latino, urb...
# 8   [colombian pop, reggaeton, reggaeton colombian...
# 9   [reggaeton, reggaeton colombiano, trap latino,...
# 10                                                 []
# 11  [colombian pop, latin pop, latin viral pop, re...
# 12  [reggaeton, reggaeton flow, trap latino, urban...
# 13  [colombian pop, latin pop, reggaeton, reggaeto...
# 14  [pop venezolano, reggaeton, trap latino, urban...
# 15                                                 []
# 16  [bachata, latin hip hop, latin pop, trap latin...
# 17  [latin hip hop, reggaeton, trap latino, urbano...
# 18         [colombian pop, dance pop, latin pop, pop]
# 19                     [pop argentino, urbano latino]
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/artists/0tmwSHipWxN...  0tmwSHipWxN12fsoLcFU3B
# 1   https://api.spotify.com/v1/artists/1r4hJ1h58CW...  1r4hJ1h58CWwUQe3MxPuau
# 2   https://api.spotify.com/v1/artists/4obzFoKoKRH...  4obzFoKoKRHIphyHzJ35G3
# 3   https://api.spotify.com/v1/artists/1mcTU81TzQh...  1mcTU81TzQhprhouKaTkpq
# 4   https://api.spotify.com/v1/artists/2LRoIwlKmHj...  2LRoIwlKmHjgvigdNGBHNo
# 5   https://api.spotify.com/v1/artists/2NfSBtmWe7o...  2NfSBtmWe7oPw1EmetJVso
# 6   https://api.spotify.com/v1/artists/4q3ewBCX7sL...  4q3ewBCX7sLwd24euuV69X
# 7   https://api.spotify.com/v1/artists/1i8SpTcr7yv...  1i8SpTcr7yvPOmcqrbnVXY
# 8   https://api.spotify.com/v1/artists/3m5qlPf2Oki...  3m5qlPf2OkihLz3dRYnkPA
# 9   https://api.spotify.com/v1/artists/1vyhD5VmyZ7...  1vyhD5VmyZ7KMfW5gqLgo5
# 10  https://api.spotify.com/v1/artists/7jAs1uPnpfN...  7jAs1uPnpfNmT6e5qtEPxq
# 11  https://api.spotify.com/v1/artists/28gNT5KBp7I...  28gNT5KBp7IjEOQoevXf9N
# 12  https://api.spotify.com/v1/artists/37230BxxYs9...  37230BxxYs9ksS7OkZw3IU
# 13  https://api.spotify.com/v1/artists/07YUOmWljBT...  07YUOmWljBTXwIseAUd9TW
# 14  https://api.spotify.com/v1/artists/5H1nN1SzW0q...  5H1nN1SzW0qNeUEZvuXjAj
# 15  https://api.spotify.com/v1/artists/3UTF2no3muG...  3UTF2no3muGdiFXVujl94i
# 16  https://api.spotify.com/v1/artists/5lwmRuXgjX8...  5lwmRuXgjX8xIwlnauTZIP
# 17  https://api.spotify.com/v1/artists/4VMYDCV2IED...  4VMYDCV2IEDYJArk749S6m
# 18  https://api.spotify.com/v1/artists/0EmeFodog0B...  0EmeFodog0BfCgMzAIvKQp
# 19  https://api.spotify.com/v1/artists/1DxLCyH42ya...  1DxLCyH42yaHKGK3cl5bvG
#
#                                                images              name  \
# 0   [{'url': 'https://i.scdn.co/image/ab6761610000...     Manuel Turizo
# 1   [{'url': 'https://i.scdn.co/image/ab6761610000...            Maluma
# 2   [{'url': 'https://i.scdn.co/image/ab6761610000...           Becky G
# 3   [{'url': 'https://i.scdn.co/image/ab6761610000...    Rauw Alejandro
# 4   [{'url': 'https://i.scdn.co/image/ab6761610000...              Feid
# 5   [{'url': 'https://i.scdn.co/image/ab6761610000...              Boza
# 6   [{'url': 'https://i.scdn.co/image/ab6761610000...         Bad Bunny
# 7   [{'url': 'https://i.scdn.co/image/ab6761610000...             Ozuna
# 8   [{'url': 'https://i.scdn.co/image/ab6761610000...  Ovy On The Drums
# 9   [{'url': 'https://i.scdn.co/image/ab6761610000...          J Balvin
# 10  [{'url': 'https://i.scdn.co/image/ab6761610000...         ATL Jacob
# 11  [{'url': 'https://i.scdn.co/image/ab6761610000...            Camilo
# 12  [{'url': 'https://i.scdn.co/image/ab6761610000...  Chencho Corleone
# 13  [{'url': 'https://i.scdn.co/image/ab6761610000...   Sebastian Yatra
# 14  [{'url': 'https://i.scdn.co/image/ab6761610000...       Danny Ocean
# 15  [{'url': 'https://i.scdn.co/image/ab6761610000...              Kapo
# 16  [{'url': 'https://i.scdn.co/image/ab6761610000...      Romeo Santos
# 17  [{'url': 'https://i.scdn.co/image/ab6761610000...      Daddy Yankee
# 18  [{'url': 'https://i.scdn.co/image/ab6761610000...           Shakira
# 19  [{'url': 'https://i.scdn.co/image/ab6761610000...     Maria Becerra
#
#     popularity    type                                    uri
# 0           84  artist  spotify:artist:0tmwSHipWxN12fsoLcFU3B
# 1           86  artist  spotify:artist:1r4hJ1h58CWwUQe3MxPuau
# 2           79  artist  spotify:artist:4obzFoKoKRHIphyHzJ35G3
# 3           90  artist  spotify:artist:1mcTU81TzQhprhouKaTkpq
# 4           92  artist  spotify:artist:2LRoIwlKmHjgvigdNGBHNo
# 5           71  artist  spotify:artist:2NfSBtmWe7oPw1EmetJVso
# 6           95  artist  spotify:artist:4q3ewBCX7sLwd24euuV69X
# 7           87  artist  spotify:artist:1i8SpTcr7yvPOmcqrbnVXY
# 8           79  artist  spotify:artist:3m5qlPf2OkihLz3dRYnkPA
# 9           88  artist  spotify:artist:1vyhD5VmyZ7KMfW5gqLgo5
# 10          74  artist  spotify:artist:7jAs1uPnpfNmT6e5qtEPxq
# 11          81  artist  spotify:artist:28gNT5KBp7IjEOQoevXf9N
# 12          80  artist  spotify:artist:37230BxxYs9ksS7OkZw3IU
# 13          80  artist  spotify:artist:07YUOmWljBTXwIseAUd9TW
# 14          78  artist  spotify:artist:5H1nN1SzW0qNeUEZvuXjAj
# 15          81  artist  spotify:artist:3UTF2no3muGdiFXVujl94i
# 16          85  artist  spotify:artist:5lwmRuXgjX8xIwlnauTZIP
# 17          88  artist  spotify:artist:4VMYDCV2IEDYJArk749S6m
# 18          88  artist  spotify:artist:0EmeFodog0BfCgMzAIvKQp
# 19          82  artist  spotify:artist:1DxLCyH42yaHKGK3cl5bvG

# %%
# Start building your playlist!!!

full_endpoint_2 = base_url + resource  + "790FomKkXshlbRYZFtlgla"+ "/top-tracks"
full_endpoint_2
# Out:
# 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla/top-tracks'

# %%
header_info_2 = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %%
a = requests.get(full_endpoint_2, headers=header_info_2)
a.status_code
# Out:
# 200

# %%
a_json = a.json()

# %%
a_json
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#     'href': 'https://api.spotify.com/v1/albums/5ylbxH7EqpsmHZCRuiYewS',
#     'id': '5ylbxH7EqpsmHZCRuiYewS',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273491678beaffcefac517a699e',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02491678beaffcefac517a699e',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851491678beaffcefac517a699e',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'Si Antes Te Hubiera Conocido',
#     'release_date': '2024-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5ylbxH7EqpsmHZCRuiYewS'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 195824,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12400968'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6WatFBLVB0x077xWeoVc2k'},
#    'href': 'https://api.spotify.com/v1/tracks/6WatFBLVB0x077xWeoVc2k',
#    'id': '6WatFBLVB0x077xWeoVc2k',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Si Antes Te Hubiera Conocido',
#    'popularity': 94,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6WatFBLVB0x077xWeoVc2k'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'},
#     'href': 'https://api.spotify.com/v1/albums/0FqAaUEyKCyUNFE1uQPZ7i',
#     'id': '0FqAaUEyKCyUNFE1uQPZ7i',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273d026bf9d7780f6a1267b4d03',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02d026bf9d7780f6a1267b4d03',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851d026bf9d7780f6a1267b4d03',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)',
#     'release_date': '2023-08-10',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:0FqAaUEyKCyUNFE1uQPZ7i'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#      'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#      'id': '12GqGscKJx3aE4t07u7eVZ',
#      'name': 'Peso Pluma',
#      'type': 'artist',
#      'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 172797,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUG12305257'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5RqSsdzTNPX1uzkmlHCFvK'},
#    'href': 'https://api.spotify.com/v1/tracks/5RqSsdzTNPX1uzkmlHCFvK',
#    'id': '5RqSsdzTNPX1uzkmlHCFvK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'QLONA',
#    'popularity': 85,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:5RqSsdzTNPX1uzkmlHCFvK'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#     'href': 'https://api.spotify.com/v1/albums/4kS7bSuU0Jm9LYMosFU2x5',
#     'id': '4kS7bSuU0Jm9LYMosFU2x5',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27382de1ca074ae63cb18fce335',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d0000485182de1ca074ae63cb18fce335',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO',
#     'release_date': '2023-02-24',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:4kS7bSuU0Jm9LYMosFU2x5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 170480,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72222552'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/505v13epFXodT9fVAJ6h8k'},
#    'href': 'https://api.spotify.com/v1/tracks/505v13epFXodT9fVAJ6h8k',
#    'id': '505v13epFXodT9fVAJ6h8k',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'AMARGURA',
#    'popularity': 85,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:505v13epFXodT9fVAJ6h8k'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0FqAaUEyKCyUNFE1uQPZ7i'},
#     'href': 'https://api.spotify.com/v1/albums/0FqAaUEyKCyUNFE1uQPZ7i',
#     'id': '0FqAaUEyKCyUNFE1uQPZ7i',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273d026bf9d7780f6a1267b4d03',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02d026bf9d7780f6a1267b4d03',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851d026bf9d7780f6a1267b4d03',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO (BICHOTA SEASON)',
#     'release_date': '2023-08-10',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:0FqAaUEyKCyUNFE1uQPZ7i'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 154374,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12305253'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/54zcJnb3tp9c5OVKREZ1Is'},
#    'href': 'https://api.spotify.com/v1/tracks/54zcJnb3tp9c5OVKREZ1Is',
#    'id': '54zcJnb3tp9c5OVKREZ1Is',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'MI EX TENÍA RAZÓN',
#    'popularity': 83,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:54zcJnb3tp9c5OVKREZ1Is'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#     'href': 'https://api.spotify.com/v1/albums/4kS7bSuU0Jm9LYMosFU2x5',
#     'id': '4kS7bSuU0Jm9LYMosFU2x5',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27382de1ca074ae63cb18fce335',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d0000485182de1ca074ae63cb18fce335',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO',
#     'release_date': '2023-02-24',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:4kS7bSuU0Jm9LYMosFU2x5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 207626,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72205906'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3HqcNJdZ2seoGxhn0wVNDK'},
#    'href': 'https://api.spotify.com/v1/tracks/3HqcNJdZ2seoGxhn0wVNDK',
#    'id': '3HqcNJdZ2seoGxhn0wVNDK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'PROVENZA',
#    'popularity': 81,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:3HqcNJdZ2seoGxhn0wVNDK'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#     'href': 'https://api.spotify.com/v1/albums/4kS7bSuU0Jm9LYMosFU2x5',
#     'id': '4kS7bSuU0Jm9LYMosFU2x5',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27382de1ca074ae63cb18fce335',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d0000485182de1ca074ae63cb18fce335',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO',
#     'release_date': '2023-02-24',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:4kS7bSuU0Jm9LYMosFU2x5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#      'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#      'id': '0EmeFodog0BfCgMzAIvKQp',
#      'name': 'Shakira',
#      'type': 'artist',
#      'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 197933,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72222541'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0DWdj2oZMBFSzRsi2Cvfzf'},
#    'href': 'https://api.spotify.com/v1/tracks/0DWdj2oZMBFSzRsi2Cvfzf',
#    'id': '0DWdj2oZMBFSzRsi2Cvfzf',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'TQG',
#    'popularity': 81,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0DWdj2oZMBFSzRsi2Cvfzf'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4obzFoKoKRHIphyHzJ35G3'},
#       'href': 'https://api.spotify.com/v1/artists/4obzFoKoKRHIphyHzJ35G3',
#       'id': '4obzFoKoKRHIphyHzJ35G3',
#       'name': 'Becky G',
#       'type': 'artist',
#       'uri': 'spotify:artist:4obzFoKoKRHIphyHzJ35G3'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7eC4wtMG1I2Jtk4FDWbkKC'},
#     'href': 'https://api.spotify.com/v1/albums/7eC4wtMG1I2Jtk4FDWbkKC',
#     'id': '7eC4wtMG1I2Jtk4FDWbkKC',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273518859dcb13382116f450073',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02518859dcb13382116f450073',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851518859dcb13382116f450073',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'ESQUEMAS',
#     'release_date': '2022-05-13',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:7eC4wtMG1I2Jtk4FDWbkKC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4obzFoKoKRHIphyHzJ35G3'},
#      'href': 'https://api.spotify.com/v1/artists/4obzFoKoKRHIphyHzJ35G3',
#      'id': '4obzFoKoKRHIphyHzJ35G3',
#      'name': 'Becky G',
#      'type': 'artist',
#      'uri': 'spotify:artist:4obzFoKoKRHIphyHzJ35G3'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 226093,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC12200425'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7FlQk2gJ6TBrHHiidvdR2O'},
#    'href': 'https://api.spotify.com/v1/tracks/7FlQk2gJ6TBrHHiidvdR2O',
#    'id': '7FlQk2gJ6TBrHHiidvdR2O',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'MAMIII',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0a699c30d354c4cb36439d03522e65b377ac0fd8?cid=2fde000873cf4db7b4e490116ba9976c',
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:7FlQk2gJ6TBrHHiidvdR2O'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#     'href': 'https://api.spotify.com/v1/albums/4kS7bSuU0Jm9LYMosFU2x5',
#     'id': '4kS7bSuU0Jm9LYMosFU2x5',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27382de1ca074ae63cb18fce335',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d0000485182de1ca074ae63cb18fce335',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO',
#     'release_date': '2023-02-24',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:4kS7bSuU0Jm9LYMosFU2x5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 164386,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72300862'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6otePxalBK8AVa20xhZYVQ'},
#    'href': 'https://api.spotify.com/v1/tracks/6otePxalBK8AVa20xhZYVQ',
#    'id': '6otePxalBK8AVa20xhZYVQ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'MIENTRAS ME CURO DEL CORA',
#    'popularity': 80,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6otePxalBK8AVa20xhZYVQ'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4kS7bSuU0Jm9LYMosFU2x5'},
#     'href': 'https://api.spotify.com/v1/albums/4kS7bSuU0Jm9LYMosFU2x5',
#     'id': '4kS7bSuU0Jm9LYMosFU2x5',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27382de1ca074ae63cb18fce335',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e0282de1ca074ae63cb18fce335',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d0000485182de1ca074ae63cb18fce335',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'MAÑANA SERÁ BONITO',
#     'release_date': '2023-02-24',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:4kS7bSuU0Jm9LYMosFU2x5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5lwmRuXgjX8xIwlnauTZIP'},
#      'href': 'https://api.spotify.com/v1/artists/5lwmRuXgjX8xIwlnauTZIP',
#      'id': '5lwmRuXgjX8xIwlnauTZIP',
#      'name': 'Romeo Santos',
#      'type': 'artist',
#      'uri': 'spotify:artist:5lwmRuXgjX8xIwlnauTZIP'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 200120,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72222547'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4NoOME4Dhf4xgxbHDT7VGe'},
#    'href': 'https://api.spotify.com/v1/tracks/4NoOME4Dhf4xgxbHDT7VGe',
#    'id': '4NoOME4Dhf4xgxbHDT7VGe',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'X SI VOLVEMOS',
#    'popularity': 78,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4NoOME4Dhf4xgxbHDT7VGe'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#       'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#       'id': '790FomKkXshlbRYZFtlgla',
#       'name': 'KAROL G',
#       'type': 'artist',
#       'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#       'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#       'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#       'name': 'Tiësto',
#       'type': 'artist',
#       'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2mKcYIgv7ItYDQXke3uprl'},
#     'href': 'https://api.spotify.com/v1/albums/2mKcYIgv7ItYDQXke3uprl',
#     'id': '2mKcYIgv7ItYDQXke3uprl',
#     'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273c5426d9daa879064ccf12fb1',
#       'width': 640,
#       'height': 640},
#      {'url': 'https://i.scdn.co/image/ab67616d00001e02c5426d9daa879064ccf12fb1',
#       'width': 300,
#       'height': 300},
#      {'url': 'https://i.scdn.co/image/ab67616d00004851c5426d9daa879064ccf12fb1',
#       'width': 64,
#       'height': 64}],
#     'is_playable': True,
#     'name': 'CONTIGO (with Tiësto)',
#     'release_date': '2024-02-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2mKcYIgv7ItYDQXke3uprl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#      'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#      'id': '790FomKkXshlbRYZFtlgla',
#      'name': 'KAROL G',
#      'type': 'artist',
#      'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2o5jDhtHVPhrJdv3cEQ99Z'},
#      'href': 'https://api.spotify.com/v1/artists/2o5jDhtHVPhrJdv3cEQ99Z',
#      'id': '2o5jDhtHVPhrJdv3cEQ99Z',
#      'name': 'Tiësto',
#      'type': 'artist',
#      'uri': 'spotify:artist:2o5jDhtHVPhrJdv3cEQ99Z'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 192786,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUG12400966'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4UkUxO2WlKLc0Q1iEutGGh'},
#    'href': 'https://api.spotify.com/v1/tracks/4UkUxO2WlKLc0Q1iEutGGh',
#    'id': '4UkUxO2WlKLc0Q1iEutGGh',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'CONTIGO (with Tiësto)',
#    'popularity': 79,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4UkUxO2WlKLc0Q1iEutGGh'}]}

# %%
a_json.keys()
# Out:
# dict_keys(['tracks'])

# %%
a_list = a_json["tracks"]

# %%
type(a_list)
# Out:
# list

# %%
len(a_list)
# Out:
# 10

# %%
a_list[0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#     'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#     'id': '790FomKkXshlbRYZFtlgla',
#     'name': 'KAROL G',
#     'type': 'artist',
#     'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5ylbxH7EqpsmHZCRuiYewS'},
#   'href': 'https://api.spotify.com/v1/albums/5ylbxH7EqpsmHZCRuiYewS',
#   'id': '5ylbxH7EqpsmHZCRuiYewS',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b273491678beaffcefac517a699e',
#     'width': 640,
#     'height': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e02491678beaffcefac517a699e',
#     'width': 300,
#     'height': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d00004851491678beaffcefac517a699e',
#     'width': 64,
#     'height': 64}],
#   'is_playable': True,
#   'name': 'Si Antes Te Hubiera Conocido',
#   'release_date': '2024-06-21',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5ylbxH7EqpsmHZCRuiYewS'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/790FomKkXshlbRYZFtlgla'},
#    'href': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla',
#    'id': '790FomKkXshlbRYZFtlgla',
#    'name': 'KAROL G',
#    'type': 'artist',
#    'uri': 'spotify:artist:790FomKkXshlbRYZFtlgla'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 195824,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUG12400968'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6WatFBLVB0x077xWeoVc2k'},
#  'href': 'https://api.spotify.com/v1/tracks/6WatFBLVB0x077xWeoVc2k',
#  'id': '6WatFBLVB0x077xWeoVc2k',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Si Antes Te Hubiera Conocido',
#  'popularity': 94,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:6WatFBLVB0x077xWeoVc2k'}

# %%
a_list[0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'track_number', 'type', 'uri'])

# %%
for i in range(len(a_list)):
    print(a_list[i]["name"])
# Out:
# Si Antes Te Hubiera Conocido
# QLONA
# AMARGURA
# MI EX TENÍA RAZÓN
# PROVENZA
# TQG
# MAMIII
# MIENTRAS ME CURO DEL CORA
# X SI VOLVEMOS
# CONTIGO (with Tiësto)

# %%
df_top_tracks = pd.DataFrame(a_list)

# %%
df_top_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'single', 'artists': [{'externa...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
# 5  [{'external_urls': {'spotify': 'https://open.s...
# 6  [{'external_urls': {'spotify': 'https://open.s...
# 7  [{'external_urls': {'spotify': 'https://open.s...
# 8  [{'external_urls': {'spotify': 'https://open.s...
# 9  [{'external_urls': {'spotify': 'https://open.s...
#
#                                    available_markets  disc_number  \
# 0  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 5  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 6  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 7  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 8  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 9  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#    duration_ms  explicit              external_ids  \
# 0       195824     False  {'isrc': 'USUG12400968'}
# 1       172797      True  {'isrc': 'USUG12305257'}
# 2       170480      True  {'isrc': 'USUM72222552'}
# 3       154374     False  {'isrc': 'USUG12305253'}
# 4       207626     False  {'isrc': 'USUM72205906'}
# 5       197933      True  {'isrc': 'USUM72222541'}
# 6       226093     False  {'isrc': 'USRC12200425'}
# 7       164386     False  {'isrc': 'USUM72300862'}
# 8       200120      True  {'isrc': 'USUM72222547'}
# 9       192786     False  {'isrc': 'USUG12400966'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6W...
# 1  {'spotify': 'https://open.spotify.com/track/5R...
# 2  {'spotify': 'https://open.spotify.com/track/50...
# 3  {'spotify': 'https://open.spotify.com/track/54...
# 4  {'spotify': 'https://open.spotify.com/track/3H...
# 5  {'spotify': 'https://open.spotify.com/track/0D...
# 6  {'spotify': 'https://open.spotify.com/track/7F...
# 7  {'spotify': 'https://open.spotify.com/track/6o...
# 8  {'spotify': 'https://open.spotify.com/track/4N...
# 9  {'spotify': 'https://open.spotify.com/track/4U...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6WatFBLVB0x0...  6WatFBLVB0x077xWeoVc2k
# 1  https://api.spotify.com/v1/tracks/5RqSsdzTNPX1...  5RqSsdzTNPX1uzkmlHCFvK
# 2  https://api.spotify.com/v1/tracks/505v13epFXod...  505v13epFXodT9fVAJ6h8k
# 3  https://api.spotify.com/v1/tracks/54zcJnb3tp9c...  54zcJnb3tp9c5OVKREZ1Is
# 4  https://api.spotify.com/v1/tracks/3HqcNJdZ2seo...  3HqcNJdZ2seoGxhn0wVNDK
# 5  https://api.spotify.com/v1/tracks/0DWdj2oZMBFS...  0DWdj2oZMBFSzRsi2Cvfzf
# 6  https://api.spotify.com/v1/tracks/7FlQk2gJ6TBr...  7FlQk2gJ6TBrHHiidvdR2O
# 7  https://api.spotify.com/v1/tracks/6otePxalBK8A...  6otePxalBK8AVa20xhZYVQ
# 8  https://api.spotify.com/v1/tracks/4NoOME4Dhf4x...  4NoOME4Dhf4xgxbHDT7VGe
# 9  https://api.spotify.com/v1/tracks/4UkUxO2WlKLc...  4UkUxO2WlKLc0Q1iEutGGh
#
#    is_local  is_playable                          name  popularity  \
# 0     False         True  Si Antes Te Hubiera Conocido          94
# 1     False         True                         QLONA          85
# 2     False         True                      AMARGURA          85
# 3     False         True             MI EX TENÍA RAZÓN          83
# 4     False         True                      PROVENZA          81
# 5     False         True                           TQG          81
# 6     False         True                        MAMIII          79
# 7     False         True     MIENTRAS ME CURO DEL CORA          80
# 8     False         True                 X SI VOLVEMOS          78
# 9     False         True         CONTIGO (with Tiësto)          79
#
#    track_number   type                                   uri  \
# 0             1  track  spotify:track:6WatFBLVB0x077xWeoVc2k
# 1             5  track  spotify:track:5RqSsdzTNPX1uzkmlHCFvK
# 2            15  track  spotify:track:505v13epFXodT9fVAJ6h8k
# 3             3  track  spotify:track:54zcJnb3tp9c5OVKREZ1Is
# 4            12  track  spotify:track:3HqcNJdZ2seoGxhn0wVNDK
# 5             6  track  spotify:track:0DWdj2oZMBFSzRsi2Cvfzf
# 6            14  track  spotify:track:7FlQk2gJ6TBrHHiidvdR2O
# 7             1  track  spotify:track:6otePxalBK8AVa20xhZYVQ
# 8             2  track  spotify:track:4NoOME4Dhf4xgxbHDT7VGe
# 9             1  track  spotify:track:4UkUxO2WlKLc0Q1iEutGGh
#
#                                          preview_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  https://p.scdn.co/mp3-preview/0a699c30d354c4cb...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
def top_track(id_artist,heders):
full_endpoint_artist ="https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla/top-tracks"+
    for i in range(len(a_list)):
        list_song = a_list[i]["name"]
    for i in range(len(r_list)):
        list_name = r_list[i]["name"]

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
